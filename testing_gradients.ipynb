# %%
from gradients import optimize as opt

# %% [markdown]
# Первая функция: https://realpython.com/gradient-descent-algorithm-python/
#
# Третья - пятая функции: https://sudharsanasai.medium.com/deep-learning-gradient-descent-methods-comprehensive-tests-and-analysis-4e52cf5a1ad9

# %%
test_func = ['x**4 - 5*x**2-3*x', 
             'x**2 + y**2', 
             '2*x**2 - 1.05*x**4 + (x**6 / 6) + x*y+y**2', 
             '-cos(x)*cos(y)*exp(-((x - pi)**2 + (y-pi)**2))', 
             '(x+2y-7)**2+(2x+y-5)**2']

# %% [markdown]
# ## Метод градиентного спуска с постоянным шагом

# %%
# %%time
opt.constant_descent('x**4 - 5*x**2-3*x', 0.1, plot=True, x_init=[0])
# Out:
# Достигнуто максимальное количество итераций
# f(X) = -7.35219947674506, X = {x: 1.0393324789193148}
# CPU times: user 380 ms, sys: 20 ms, total: 400 ms
# Wall time: 458 ms
# (-7.35219947674506, {x: 1.0393324789193148})

# %%
# %%time
opt.constant_descent('x**2 + y**2', 0.1, plot=True)
# Out:
# Найдено значение с заданной точностью
# f(X) = 6.36573742604527E-10, X = {y: 1.7840596158824504e-05, x: 1.7840596158824504e-05}
# CPU times: user 2.44 s, sys: 128 ms, total: 2.57 s
# Wall time: 1.42 s
# (6.36573742604527e-10, {y: 1.7840596158824504e-05, x: 1.7840596158824504e-05})

# %%
# %%time
opt.constant_descent('2*x**2 - 1.05*x**4 + (x**6 / 6) + x*y+y**2', 0.01, plot=True)
# Out:
# Найдено значение с заданной точностью
# f(X) = 1.77031983586180E-7, X = {y: 0.0004365575089800562, x: -0.0001808064317132347}
# CPU times: user 2.75 s, sys: 20 ms, total: 2.77 s
# Wall time: 1.68 s
# (1.77031983586180e-7, {y: 0.0004365575089800562, x: -0.0001808064317132347})

# %%
# %%time
opt.constant_descent('-cos(x)*cos(y)*exp(-((x - pi)**2 + (y-pi)**2))', 
                     0.1, print_info=False, record_info=False, plot=True, x_init=[2, 2])
# Out:
# Найдено значение с заданной точностью
# f(X) = -0.9999999996574980, X = {y: 3.1415819686782913, x: 3.1415819686782913}
# CPU times: user 2.79 s, sys: 84 ms, total: 2.87 s
# Wall time: 1.7 s
# (-0.9999999996574980, {y: 3.1415819686782913, x: 3.1415819686782913})

# %%
# %%time
opt.constant_descent('(x+2y-7)**2+(2x+y-5)**2', 
                     0.1, print_info=False, record_info=False, plot=True)
# Out:
# Найдено значение с заданной точностью
# f(X) = 7.33919557005713E-11, X = {y: 3.0000000000000004, x: 1.0000038312388515}
# CPU times: user 4.05 s, sys: 20 ms, total: 4.07 s
# Wall time: 3.16 s
# (7.33919557005713e-11, {y: 3.0000000000000004, x: 1.0000038312388515})

# %% [markdown]
# Выводы:
# 1) У первой функции выдает правильный результат.
#
# 2) У второй функции правильный ответ. Работает корректно даже без начальной точки.
#
# 3) У третьей функции правильный ответ. Работает корректно даже без начальной точки.
#
# 4) У четвертой функции выдает правильный ответ, только при условии, что начальная точка находится близко к минимуму. Иначе может не сойтись к минимуму.
#
# 5) У пятой функции выдает правильный резульат.
#
# Среднее время выполнения: 1,4424 секунды при условии отрисовок.

# %% [markdown]
# ## Метод градиентного спуска с дроблением шага

# %%
# %%time
opt.splitting_step_descent('x**4 - 5*x**2-3*x', 
                           0.1, 0.01, 0.95, plot=True, x_init=[0])
# Out:
# Найдено значение с заданной точностью
# f(X) = -11.2003347084496, X = {x: 1.713943850785162}
# CPU times: user 268 ms, sys: 4 ms, total: 272 ms
# Wall time: 267 ms
# (-11.2003347084496, {x: 1.713943850785162})

# %%
# %%time
opt.splitting_step_descent('x**2 + y**2', 
                           0.1, 0.01, 0.95, plot=True)
# Out:
# Найдено значение с заданной точностью
# f(X) = 6.36573742604527E-10, X = {y: 1.7840596158824504e-05, x: 1.7840596158824504e-05}
# CPU times: user 2.03 s, sys: 32 ms, total: 2.06 s
# Wall time: 1.1 s
# (6.36573742604527e-10, {y: 1.7840596158824504e-05, x: 1.7840596158824504e-05})

# %%
# %%time
opt.splitting_step_descent('2*x**2 - 1.05*x**4 + (x**6 / 6) + x*y+y**2', 
                           0.1, 0.01, 0.95, plot=True)
# Out:
# Найдено значение с заданной точностью
# f(X) = 1.05730580171077E-9, X = {y: 3.373714326076398e-05, x: -1.3974381517350185e-05}
# CPU times: user 2.76 s, sys: 64 ms, total: 2.82 s
# Wall time: 1.83 s
# (1.05730580171077e-9, {y: 3.373714326076398e-05, x: -1.3974381517350185e-05})

# %%
# %%time
opt.splitting_step_descent('-cos(x)*cos(y)*exp(-((x - pi)**2 + (y-pi)**2))', 
                           1, 0.1, 0.95, plot=True, x_init=[2, 2])
# Out:
# Найдено значение с заданной точностью
# f(X) = -0.9999999999943410, X = {y: 3.141594027037767, x: 3.141594027037767}
# CPU times: user 2.56 s, sys: 28 ms, total: 2.59 s
# Wall time: 1.61 s
# (-0.9999999999943410, {y: 3.141594027037767, x: 3.141594027037767})

# %%
# %%time
opt.splitting_step_descent('(x+2y-7)**2+(2x+y-5)**2',
                           0.2, 0.01, 0.95, plot=True)
# Out:
# Найдено значение с заданной точностью
# f(X) = 1.03703639721481E-10, X = {y: 2.9999975997264077, x: 0.9999975997264078}
# CPU times: user 5.34 s, sys: 44 ms, total: 5.38 s
# Wall time: 4.4 s
# (1.03703639721481e-10, {y: 2.9999975997264077, x: 0.9999975997264078})

# %% [markdown]
# Выводы:
#
# Все аналогично предыдущему методу.
#
# Среднее время выполнения: 1,929

# %% [markdown]
# ## Метод наискорейшего градиентного спуска

# %%
# %%time
opt.steepest_descent('x**4-5*x**2-3*x', plot=True)
# Out:
# Найдено значение с заданной точностью
# f(l) = -11.2003347075035, l = 0.07932552430882119
# Найдено значение с заданной точностью
# f(l) = -11.2003347086956, l = 0.03964106118413408
# Найдено значение с заданной точностью
# f(X) = -11.2003347086957, X = {x: 1.713939445620187}
# CPU times: user 356 ms, sys: 8 ms, total: 364 ms
# Wall time: 363 ms
# (-11.2003347086957, {x: 1.713939445620187})

# %%
# %%time
opt.steepest_descent('x**2 + y**2', plot=True)
# Out:
# Найдено значение с заданной точностью
# f(l) = 0, l = 0.5
# Градиент вышел на плато
# f(X) = 0, X = {y: 0.0, x: 0.0}
# CPU times: user 2.18 s, sys: 32 ms, total: 2.21 s
# Wall time: 1.19 s
# (0, {y: 0.0, x: 0.0})

# %%
# %%time
opt.steepest_descent('2*x**2 - 1.05*x**4 + (x**6 / 6) + x*y+y**2', 
                     print_info=False, record_info=False, plot=True)
# Out:
# Найдено значение с заданной точностью
# f(l) = 0.117971722358335, l = 0.4289168801951618
# Найдено значение с заданной точностью
# f(l) = 0.0223662236013108, l = 0.41060405003539163
# Найдено значение с заданной точностью
# f(l) = 0.00463216301686498, l = 0.2932575199345065
# Найдено значение с заданной точностью
# f(l) = 0.000957132343897126, l = 0.387219403924985
# Найдено значение с заданной точностью
# f(l) = 0.000198397118447676, l = 0.2931097002751377
# Найдено значение с заданной точностью
# f(l) = 0.0000411192507544701, l = 0.3864045537911107
# Найдено значение с заданной точностью
# f(l) = 0.00000852347175882774, l = 0.29310373941415113
# Найдено значение с заданной точностью
# f(l) = 0.00000176681866610145, l = 0.3863636974421023
# Найдено значение с заданной точностью
# f(l) = 3.66241112211569E-7, l = 0.29310373941415113
# Найдено значение с заданной точностью
# f(l) = 7.59176662637576E-8, l = 0.3863636974421023
# Найдено значение с заданной точностью
# f(l) = 1.57368208617979E-8, l = 0.29310373941415113
# Найдено значение с заданной точностью
# f(l) = 3.26207464894843E-9, l = 0.38636001342741033
# Найдено значение с заданной точностью
# f(l) = 6.76199000631985E-10, l = 0.29310373941415113
# Найдено значение с заданной точностью
# f(l) = 1.40166732164937E-10, l = 0.38636965830308884
# Найдено значение с заданной точностью
# f(l) = 2.90544080336133E-11, l = 0.29310005539945927
# Найдено значение с заданной точностью
# f(l) = 6.02258193627442E-12, l = 0.38636965830308884
# Найдено значение с заданной точностью
# f(X) = 6.02258193627443E-12, X = {y: -2.3771734758006912e-06, x: -1.3987194587353482e-07}
# CPU times: user 4.35 s, sys: 40 ms, total: 4.39 s
# Wall time: 3.42 s
# (6.02258193627443e-12,
#  {y: -2.3771734758006912e-06, x: -1.3987194587353482e-07})

# %%
# %%time
opt.steepest_descent('-cos(x)*cos(y)*exp(-((x - pi)**2 + (y-pi)**2))', 
                     eps=0.1, print_info=False, record_info=False, plot=True, x_init=[2,2])
# Out:
# Найдено значение с заданной точностью
# f(l) = -0.02078471582430024, l = 0.9999951775621607
# Найдено значение с заданной точностью
# f(l) = -0.03948185292083673, l = 0.9999951775621607
# Найдено значение с заданной точностью
# f(l) = -0.09718933192325469, l = 0.9999951775621607
# Найдено значение с заданной точностью
# f(l) = -0.3573814014611719, l = 0.9999951775621607
# Найдено значение с заданной точностью
# f(l) = -0.9999999999964830, l = 0.8941277474799567
# Найдено значение с заданной точностью
# f(l) = -1.00000000000000, l = 0.3349549962046832
# Найдено значение с заданной точностью
# f(X) = -0.9999999999999999, X = {y: 3.1415926483223022, x: 3.1415926483223022}
# CPU times: user 3.45 s, sys: 68 ms, total: 3.52 s
# Wall time: 2.44 s
# (-0.9999999999999999, {y: 3.1415926483223022, x: 3.1415926483223022})

# %%
# %%time
opt.steepest_descent('(x+2y-7)**2+(2x+y-5)**2', 
                     print_info=False, record_info=False, plot=True, eps=0.1)
# Out:
# Найдено значение с заданной точностью
# f(l) = 1.57808222383980, l = 0.05616672654110837
# Найдено значение с заданной точностью
# f(l) = 0.125380563438606, l = 0.4552474049393683
# Найдено значение с заданной точностью
# f(l) = 0.00996141853577401, l = 0.056170410555800264
# Найдено значение с заданной точностью
# f(l) = 0.000794556598010771, l = 0.4550706506529642
# Найдено значение с заданной точностью
# f(l) = 0.0000633769435111515, l = 0.056170410555800264
# Найдено значение с заданной точностью
# f(X) = 0.0000633769435111477, X = {y: 2.9944443506339806, x: 1.0056950803054492}
# CPU times: user 4.7 s, sys: 16 ms, total: 4.72 s
# Wall time: 3.77 s
# (6.33769435111477e-5, {y: 2.9944443506339806, x: 1.0056950803054492})

# %% [markdown]
# Выводы:
#
# Все аналогично предыдущим методам.
#
# Среднее время выполнения: 1,874. Большую часть времени отнимает решение одномерной оптимизационной задачи на нахождение learning rate.
#
# Также можно отметить что точность лучше чем у других.

# %% [markdown]
# ## Поиск экстремума функции при помощи алгоритма Ньютона-сопряженного градиента

# %%
# %%time
opt.conjugate_gradients('x**4-5*x**2-3*x', plot=True, x_init=[0])
# Out:
# Найдено значение с заданной точностью
# f(X) = -11.20033470869566, X = {x: 1.7139394352179806}
# CPU times: user 252 ms, sys: 4 ms, total: 256 ms
# Wall time: 263 ms
# (-11.20033470869566, {x: 1.7139394352179806})

# %%
# %%time
opt.conjugate_gradients('x**2+y**2', plot=True)
# Out:
# Найдено значение с заданной точностью
# f(X) = 1.6332125329487896e-17, X = {y: 2.8576323529705405e-09, x: 2.8576323529705405e-09}
# CPU times: user 2.2 s, sys: 48 ms, total: 2.25 s
# Wall time: 1.28 s
# (1.6332125329487896e-17,
#  {y: 2.8576323529705405e-09, x: 2.8576323529705405e-09})

# %%
# %%time
opt.conjugate_gradients('2*x**2 - 1.05*x**4 + (x**6 / 6) + x*y+y**2', plot=True)
# Out:
# Найдено значение с заданной точностью
# f(X) = 0.0, X = {y: 0.0, x: 0.0}
# CPU times: user 2.61 s, sys: 32 ms, total: 2.64 s
# Wall time: 1.66 s
# (0.0, {y: 0.0, x: 0.0})

# %%
# %%time
opt.conjugate_gradients('-cos(x)*cos(y)*exp(-((x - pi)**2 + (y-pi)**2))', 
                        plot=True, x_init=[2, 2])
# Out:
# Найдено значение с заданной точностью
# f(X) = -0.9999999999999771, X = {y: 3.1415927410125732, x: 3.1415927410125732}
# CPU times: user 2.39 s, sys: 52 ms, total: 2.44 s
# Wall time: 1.45 s
# (-0.9999999999999771, {y: 3.1415927410125732, x: 3.1415927410125732})

# %%
# %%time
opt.conjugate_gradients('(x+2y-7)**2+(2x+y-5)**2', 
                        plot=True)
# Out:
# Найдено значение с заданной точностью
# f(X) = 8.193445906844397e-14, X = {y: 3.000000089406967, x: 1.0000000447034836}
# CPU times: user 4.18 s, sys: 32 ms, total: 4.22 s
# Wall time: 3.27 s
# (8.193445906844397e-14, {y: 3.000000089406967, x: 1.0000000447034836})

# %% [markdown]
# Выводы:
#
# Все аналогично предыдущим методам.
#
# Среднее время выполнения: 1,4452.
#
# Также можно отметить что точность лучше чем у других.
