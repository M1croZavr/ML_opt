# %%
import gradients.optimize as optimize

# %% [markdown]
# ## Метод градиентного спуска с постоянным шагом

# %%
fun_anl = input('Enter the function in analytical form: f = ')
lr = float(input('Enter the constant learning rate for descent'))
# eps = float(input('Change precision of result(default=1e-5), 1 - change, 0 - use default: '))
# if eps:
#     eps = float(input('Enter the precision of result(default=1e-5)(float or int)'))
# else:
#     eps = 1e-5
# max_iter = int(input('Change maximum iteration of algorithm(default=500), 1 - change, 0 - use default: '))
# if max_iter:
#     int(input('Enter your maximum iteration of algorithm'))
# else:
#     max_iter = 500
# print_info = bool(int(input('Should we print information in each iteration , 1 - yes, 0 - no: ')))
# record_info = bool(int(input('Make pd.DataFrame with recorder information , 1 - yes, 0 - no: ')))
# x_init = list(map(int, input('Enter the Initial x vector(default=None), leave None to initialize by ones)(float or int)').split()))
optimize.constant_descent(fun_anl, lr, x_init = [0], plot = True)
# Out:
# Enter the function in analytical form: f = x**4 - 5*x**2-3*x
# Enter the constant learning rate for descent0.1
# Достигнуто максимальное количество итераций
# f(X) = -7.35219947674506, X = {x: 1.0393324789193148}
# (-7.35219947674506, {x: 1.0393324789193148})

# %% [markdown]
# ## Метод градиентного спуска с дроблением шага

# %%
fun_anl = input('Enter the function in analytical form: f = ')
lr = float(input('Enter the constant learning rate for descent'))
e = float(input('Enter the constant which helps to choose lr each step'))
d = float(input('Enter the constant which splits lr each step'))
# eps = float(input('Change precision of result(default=1e-5), 1 - change, 0 - use default: '))
# if eps:
#     eps = float(input('Enter the precision of result(default=1e-5)(float or int)'))
# else:
#     eps = 1e-5
# max_iter = int(input('Change maximum iteration of algorithm(default=500), 1 - change, 0 - use default: '))
# if max_iter:
#     int(input('Enter your maximum iteration of algorithm'))
# else:
#     max_iter = 500
# print_info = bool(int(input('Should we print information in each iteration , 1 - yes, 0 - no: ')))
# record_info = bool(int(input('Make pd.DataFrame with recorder information , 1 - yes, 0 - no: ')))
# plot = bool(int(input('Should we draw a plot , 1 - yes, 0 - no: ')))
# x_init = list(map(int, input('Enter the Initial x vector(default=None), leave None to initialize by ones)(float or int)').split()))
optimize.splitting_step_descent(fun_anl, lr, e, d, plot = True, x_init = [0])
# Out:
# Enter the function in analytical form: f = x**4 - 5*x**2-3*x
# Enter the constant learning rate for descent0.1
# Enter the constant which helps to choose lr each step0.5
# Enter the constant which splits lr each step0.2
# Найдено значение с заданной точностью
# f(X) = -11.2003347075542, X = {x: 1.7139299277339668}
# (-11.2003347075542, {x: 1.7139299277339668})

# %% [markdown]
# ## Метод наискорейшего градиентного спуска

# %%
fun_anl = input('Enter the function in analytical form: f = ')
# eps = float(input('Change precision of result(default=1e-5), 1 - change, 0 - use default: '))
# if eps:
#     eps = float(input('Enter the precision of result(default=1e-5)(float or int)'))
# else:
#     eps = 1e-5
# max_iter = int(input('Change maximum iteration of algorithm(default=500), 1 - change, 0 - use default: '))
# if max_iter:
#     int(input('Enter your maximum iteration of algorithm'))
# else:
#     max_iter = 500
# print_info = bool(int(input('Should we print information in each iteration , 1 - yes, 0 - no: ')))
# record_info = bool(int(input('Make pd.DataFrame with recorder information , 1 - yes, 0 - no: ')))
# plot = bool(int(input('Should we draw a plot , 1 - yes, 0 - no: ')))
# x_init = list(map(int, input('Enter the Initial x vector(default=None), leave None to initialize by ones)(float or int)').split()))
# lr_fined = str(input('Choose(copy) One dimensional optimization solver(parabolic, brent, golden_search):'))
optimize.steepest_descent(fun_anl, plot = True)
# Out:
# Enter the function in analytical form: f = x**2 + y**2
# Найдено значение с заданной точностью
# f(l) = 0, l = 0.5
# Градиент вышел на плато
# f(X) = 0, X = {y: 0.0, x: 0.0}
# (0, {y: 0.0, x: 0.0})

# %% [markdown]
# ## Поиск экстремума функции при помощи алгоритма Ньютона-сопряженного градиента

# %%
fun_anl = input('Enter the function in analytical form: f = ')
# eps = float(input('Change precision of result(default=1e-5), 1 - change, 0 - use default: '))
# if eps:
#     eps = float(input('Enter the precision of result(default=1e-5)(float or int)'))
# else:
#     eps = 1e-5
# max_iter = int(input('Change maximum iteration of algorithm(default=500), 1 - change, 0 - use default: '))
# if max_iter:
#     int(input('Enter your maximum iteration of algorithm'))
# else:
#     max_iter = 500
# print_info = bool(int(input('Should we print information in each iteration , 1 - yes, 0 - no: ')))
# record_info = bool(int(input('Make pd.DataFrame with recorder information , 1 - yes, 0 - no: ')))
# plot = bool(int(input('Should we draw a plot , 1 - yes, 0 - no: ')))
# x_init = list(map(int, input('Enter the Initial x vector(default=None), leave None to initialize by ones)(float or int)').split()))
optimize.conjugate_gradients(fun_anl, plot = True)
# Out:
# Enter the function in analytical form: f = x**2 + y**2
# Найдено значение с заданной точностью
# f(X) = 1.6332125329487896e-17, X = {y: 2.8576323529705405e-09, x: 2.8576323529705405e-09}
# (1.6332125329487896e-17,
#  {y: 2.8576323529705405e-09, x: 2.8576323529705405e-09})
