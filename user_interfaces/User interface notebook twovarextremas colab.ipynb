# %% [markdown]
# <a href="https://colab.research.google.com/github/M1croZavr/ML_opt/blob/master/twovarextremas/User%20interface%20notebook%20colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ls
# Out:
# gdrive	sample_data

# %%
# %cd gdrive/My Drive/mlopts
# Out:
# /content/gdrive/My Drive/mlopts

# %%
! git clone https://github.com/M1croZavr/ML_opt.git
# Out:
# Cloning into 'ML_opt'...
# remote: Enumerating objects: 99, done.
# remote: Counting objects: 100% (99/99), done.
# remote: Compressing objects: 100% (74/74), done.
# remote: Total 99 (delta 45), reused 61 (delta 19), pack-reused 0
# Unpacking objects: 100% (99/99), done.

# %%
# %cd ML_opt/twovarextremas/
# Out:
# /content/gdrive/MyDrive/mlopts/ML_opt/twovarextremas

# %%
import find_extrema

# %% [markdown]
# ## Поиск локальных экстремумов функции 2-х переменных
# ### Используйте нижнюю ячейку

# %%
vars_ = input('Enter variable names separated by spaces: ').split()
f_analytic = input('Enter the function in analytical form: f = ')
constraints = [] if input('Constraints needed 1/0: ') == '1' else None
if constraints == []:
    constraints.append(tuple(map(lambda x: float(x.strip()), input('Enter constraints on variable x separated by space: ').split())))
    constraints.append(tuple(map(lambda x: float(x.strip()), input('Enter constraints on variable y separated by space: ').split())))
plot1_flag = eval(input('Plot needed True/False: ').strip().lower().capitalize())
plot2_flag = eval(input('Level lines plot needed True/False: ').strip().lower().capitalize())
find_extrema.find_local_2var(vars_, f_analytic, constraints, plot1_flag, plot2_flag)
# Out:
# Enter variable names separated by spaces: x y
# Enter the function in analytical form: f = y*(x**2)+x*(y**3) – x*y
# Constraints needed 1/0: 1
# Enter constraints on variable x separated by space: -0.5 0.5
# Enter constraints on variable y separated by space: -1 1
# Plot needed True/False: True
# Level lines plot needed True/False: True
# Point: (0.0, -1.0) | Z: 0.0 | Extrema: saddle point
# Point: (0.0, 0.0) | Z: 0.0 | Extrema: saddle point
# Point: (0.0, 1.0) | Z: 0.0 | Extrema: saddle point
# Point: (0.4, -0.4472135954999579) | Z: 0.07155417527999328 | Extrema: Maximum
# Point: (0.4, 0.4472135954999579) | Z: -0.07155417527999328 | Extrema: Minimum

# %% [markdown]
# ## Поиск локальных экстремумов функции двух переменных с ограничениями (метод Лагранжа)
# ### Используйте нижнюю ячейку

# %%
vars_ = input('Enter variable names separated by spaces: ').split()
f_analytic = input('Enter the function in analytical form: f = ')
f_c = input('Enter the limiting function in analytical form: g = ')
constraints = [] if input('Constraints needed 1/0: ').strip() == '1' else None
if constraints == []:
    constraints.append(tuple(map(lambda x: float(x.strip()), input('Enter constraints on variable x separated by space: ').split())))
    constraints.append(tuple(map(lambda x: float(x.strip()), input('Enter constraints on variable y separated by space: ').split())))
plot1_flag = eval(input('Plot needed True/False: ').strip().lower().capitalize())
plot2_flag = eval(input('Level lines plot needed True/False: ').strip().lower().capitalize())
find_extrema.find_lagrange_2var(vars_, f_analytic, f_c, constraints, plot1_flag, plot2_flag)
# Out:
# Enter variable names separated by spaces: x y
# Enter the function in analytical form: f = 5 - 3x - 4y
# Enter the limiting function in analytical form: g = x**2 + y**2 - 25
# Constraints needed 1/0: 1
# Enter constraints on variable x separated by space: -1.5 1.5
# Enter constraints on variable y separated by space: -1.5 1.5
# Plot needed True/False: True
# Level lines plot needed True/False: True
# No extrema has been found!
# Draw graphs? (yes/no): yes

# %% [markdown]
# ## Примеры работы

# %%
find_extrema.find_lagrange_2var(['x', 'y'], '5 - 3x -4y', 'x**2 + y**2 - 25', plot=True, plot_ll=True)
# Out:
# Point: (-3.0, -4.0) | Z: 30.0 | Extrema: Maximum
# Point: (3.0, 4.0) | Z: -20.0 | Extrema: Minimum

# %%
find_extrema.find_lagrange_2var(['x', 'y'], '8 - (x + 2)**2 -(y - 4)**2', 'x + 3y', plot=True, plot_ll=True)
# Out:
# Point: (-3.0, 1.0) | Z: -2.0 | Extrema: Maximum

# %%
find_extrema.find_local_2var(['x', 'y'], 'x**3 - y**2 + x - 3x', plot=True)
# Out:
# Point: (-0.816496580927726, 0.0) | Z: 1.0886621079036347 | Extrema: Maximum
# Point: (0.816496580927726, 0.0) | Z: -1.0886621079036347 | Extrema: saddle point

# %%
find_extrema.find_local_2var(['x', 'y'], 'x/y', [(1, 10), (1, 10)], True, True)
# Out:
# No extrema has been found!
# Draw graphs? (yes/no): yes
