# %%
import onedimensionaloptimization.optimize as optimize
from twovarextremas.utils_twovarextremas import preproc_fun
import sympy

# %%
# Примеры из методички
'-5x^5 + 4x^4 - 12x^3 + 11x^2 -2x + 1', -0.5, 0.5    #correct
'log2(x - 2) + log2(10 - x) - x^0.2', 6, 9.9    # неочевидная функция, нельзя аппроксимировать параболами и BFGS
'-3x*sin(0.75x) + exp(-2x)', 0, 2 * sympy.pi    #correct
'exp(3x) + 5exp(-2x)', 0, 1    #correct
'0.2x * log(x) + (x - 2.3)^2', 0.5, 2.5 #correct
# Out:
# ('0.2x * log(x) + (x - 2.3)^2', 0.5, 2.5)

# %%
# Пример, как можно записывать логарифм
a = preproc_fun('-5x^5 + 4x^4 - 12x^3 + 11x^2 -2x + 1')
a
# Out:
# -5*x**5 + 4*x**4 - 12*x**3 + 11*x**2 - 2*x + 1

# %%
f_res, x_res, df = optimize.golden_section_search('-3x*sin(0.75x) + exp(-2x)', 0, 2 * sympy.pi, record_info=True, plot=True)
# Out:
# Найдено значение с заданной точностью
# f(x) = -7.27435797007356, x = 2.7064759148064543

# %%
f_res, x_res # Правильно
# Out:
# (-7.27435797007356, 2.7064759148064543)

# %%
f_res, x_res, df = optimize.parabola_method('-3x*sin(0.75x) + exp(-2x)', 0, 2 * sympy.pi, record_info=True, plot=True)
# Out:
# Найдено значение с заданной точностью
# f(x) = -7.27435797007389, x = 2.70647551266415

# %%
f_res, x_res # Правильно
# Out:
# (-7.27435797007389, 2.70647551266415)

# %%
f_res, x_res, df = optimize.brent_method('0.2x * log(x) + (x - 2.3)^2', 0.5, 2.5, record_info=True, plot=True)
# Out:
# Найдено значение с заданной точностью
# f(x) = 0.350977880141326, x = 2.12464116257738

# %%
f_res, x_res # Правильно
# Out:
# (0.350977880141326, 2.12464116257738)

# %%
df
# Out:
#                    a                 b                 x                 w  \
# k
# 0           1.263932               2.5          1.736068          1.263932
# 1           1.736068               2.5          2.027864          1.736068
# 2           2.027864               2.5  2.12239104090496          2.027864
# 3   2.12239104090496               2.5  2.12448627265035  2.12239104090496
# 4   2.12448627265035               2.5  2.12463893301214  2.12448627265035
# 5   2.12463893301214               2.5  2.12463977183989  2.12463893301214
# 6   2.12463893301214  2.26801462097214  2.12463977183989  2.26801462097214
# 7   2.12463893301214  2.17940409107652  2.12463977183989  2.17940409107652
# 8   2.12463893301214  2.14555788041753  2.12463977183989  2.14555788041753
# 9   2.12463893301214  2.13262977833619  2.12463977183989  2.13262977833619
# 10  2.12463893301214  2.12769168275114  2.12463977183989  2.12769168275114
# 11  2.12463893301214  2.12580549807735  2.12463977183989  2.12580549807735
# 12  2.12463893301214  2.12508503964102  2.12463977183989  2.12508503964102
# 13  2.12463893301214  2.12480984900583  2.12463977183989  2.12480984900583
# 14  2.12463893301214  2.12470473553657  2.12463977183989  2.12470473553657
# 15  2.12463893301214  2.12466458576399  2.12463977183989  2.12466458576399
# 16  2.12463893301214  2.12464924991550  2.12463977183989  2.12464924991550
# 17  2.12463893301214  2.12464339214263  2.12463977183989  2.12464339214263
#
#                    v                 fx         method
# k
# 0           1.263932  0.509550252380235  Golden search
# 1           1.263932  0.360791077287901  Golden search
# 2           1.736068  0.350983175026834      Parabolic
# 3           2.027864  0.350977904810711      Parabolic
# 4   2.12239104090496  0.350977880140043      Parabolic
# 5   2.12448627265035  0.350977880139304      Parabolic
# 6   2.12463893301214  0.350977880139304  Golden search
# 7   2.26801462097214  0.350977880139304  Golden search
# 8   2.17940409107652  0.350977880139304  Golden search
# 9   2.14555788041753  0.350977880139304  Golden search
# 10  2.13262977833619  0.350977880139304  Golden search
# 11  2.12769168275114  0.350977880139304  Golden search
# 12  2.12580549807735  0.350977880139304  Golden search
# 13  2.12508503964102  0.350977880139304  Golden search
# 14  2.12480984900583  0.350977880139304  Golden search
# 15  2.12470473553657  0.350977880139304  Golden search
# 16  2.12466458576399  0.350977880139304  Golden search
# 17  2.12464924991550  0.350977880139304  Golden search

# %%
f_res, x_res, df = optimize.bfgs('0.2x * log(x) + (x - 2.3)^2', 2.5, record_info=True)
# Out:
# Точка, удовлетворяющая условию Вольфе, найдена с заданной точностью
# f(x) = 0.3509778801393048, x = 2.12463977305692

# %%
f_res, x_res # Правильно
# Out:
# (5.148340421395099, 0.24079455883233186)

# %%
df
# Out:
#           x      alpha        p         s         y         c     delta_fun
# k
# 0  0.239812   3.425885  0.07000  0.239812  6.969662  0.034408 -3.033795e-02
# 1  0.240795  94.129603  0.00001  0.000983  0.030337  0.032389 -6.357322e-07

# %%
from scipy import optimize as opt

# %%
f = lambda x: -5 * x ** 5 + 4 * x ** 4 - 12 * x ** 3 + 11 * x ** 2 - 2 * x + 1
opt.minimize(f, -0.5, method='BFGS')
# Out:
#       fun: 0.8976329718962657
#  hess_inv: array([[1.39800581]])
#       jac: array([1.8030405e-06])
#   message: 'Optimization terminated successfully.'
#      nfev: 20
#       nit: 3
#      njev: 10
#    status: 0
#   success: True
#         x: array([0.10986003])

# %%
from sympy.utilities.lambdify import lambdify

# %%
al = lambdify('x', a)
al_ = lambdify('x', a.diff('x'))

# %%
bfgs_method(al, al_, np.array([0.1]))
# Out:
# (array([0.10987976]), 2)
