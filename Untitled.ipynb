# %%
import onedimensionaloptimization.optimize as optimize
from twovarextremas.utils_twovarextremas import preproc_fun
import sympy

# %%
# Примеры из методички
'-5x^5 + 4x^4 - 12x^3 + 11x^2 -2x + 1', -0.5, 0.5
'log2(x - 2) + log2(10 - x) - x^0.2', 6, 9.9
'-3x*sin(0.75x) + exp(-2x)', 0, 2 * sympy.pi
'exp(3x) + 5exp(-2x)', 0, 1
'0.2x * log(x) + (x - 2.3)^2', 0.5, 2.5
# Out:
# '0.2x * log(x) + (x - 2.3)^2'

# %%
a = preproc_fun('log2(x - 2) + log2(10 - x) - x^0.2')
a.subs('x', 0.5)
# Out:
# -0.870550563296124 + 2.2512917986065/log(2) + (0.405465108108164 + I*pi)/log(2)

# %%
f_res, x_res, df = optimize.golden_section_search('log2(x - 2) + log2(10 - x) - x^0.2', 6, 9.9, record_info=True)
# Out:
# Найдено значение с заданной точностью

# %%
f_res, x_res # Правильно
# Out:
# (-1.58171050844928 - 0.235678498010438/log(2), 9.899995560149726)

# %%
f_res, x_res, df = optimize.parabola_method('-5x^5 + 4x^4 - 12x^3 + 11x^2 -2x + 1', -0.5, 0.5, record_info=True, plot=True)
# Out:
# Найдено значение с заданной точностью

# %%
f_res, x_res # Правильно
# Out:
# (0.897632972057668, 0.109864628876709)

# %%
df
# Out:
#           x1                 x2                 x3                f_u  \
# k
# 0  -0.071429  0.204820716011915                0.5  0.953952223263049
# 1  -0.071429  0.182743771307694  0.204820716011915  0.932069196865200
# 2  -0.071429  0.127287602891768  0.182743771307694  0.899783262980351
# 3  -0.071429  0.119957103109245  0.127287602891768  0.898362856872305
# 4  -0.071429  0.112854540831585  0.119957103109245  0.897697862239128
# 5  -0.071429  0.111294472446315  0.112854540831585  0.897647897936951
# 6  -0.071429  0.110344413240284  0.111294472446315  0.897634676837579
# 7  -0.071429  0.110069980175775  0.110344413240284  0.897633292531134
# 8  -0.071429  0.109935936570288  0.110069980175775  0.897633013897458
# 9  -0.071429  0.109891230030264  0.109935936570288  0.897632979023419
# 10 -0.071429  0.109871664070796  0.109891230030264  0.897632972899469
#
#                     u
# k
# 0   0.204820716011915
# 1   0.182743771307694
# 2   0.127287602891768
# 3   0.119957103109245
# ...

# %%
f_res, x_res, df = optimize.brent_method('(log2(x - 2) + log2(10 - x) - x^0.2)', 6, 9.9, record_info=True, plot=True)
# Out:
# Найдено значение с заданной точностью

# %%
f_res, x_res
# Out:
# (-1.58171027889886 - 0.235607574839648/log(2), 9.899988376321076)

# %%
df
# Out:
#            a    b         x         w         v  \
# k
# 0   7.489667  9.9  8.410333  7.489667  7.489667
# 1   8.410333  9.9  8.979335  8.410333  7.489667
# 2   8.979335  9.9  9.330998  8.979335  8.410333
# 3   9.330998  9.9  9.548337  9.330998  8.979335
# 4   9.548337  9.9  9.682660  9.548337  9.330998
# 5   9.682660  9.9  9.765677  9.682660  9.548337
# 6   9.765677  9.9  9.816984  9.765677  9.682660
# 7   9.816984  9.9  9.848693  9.816984  9.765677
# 8   9.848693  9.9  9.868291  9.848693  9.816984
# 9   9.868291  9.9  9.880403  9.868291  9.848693
# 10  9.880403  9.9  9.887888  9.880403  9.868291
# 11  9.887888  9.9  9.892514  9.887888  9.880403
# 12  9.892514  9.9  9.895374  9.892514  9.887888
# 13  9.895374  9.9  9.897141  9.895374  9.892514
# 14  9.897141  9.9  9.898233  9.897141  9.895374
# 15  9.898233  9.9  9.898908  9.898233  9.897141
# 16  9.898908  9.9  9.899325  9.898908  9.898233
# 17  9.899325  9.9  9.899583  9.899325  9.898908
# ...

# %%
import math

# %%
def sign(x):
    if x < 0:
        return -1
    elif x > 0:
        return 1
    else:
        return 0

# %%
sign(-4)
# Out:
# -1

# %%
1 >= 1
# Out:
# True

# %%
1 <= 1
# Out:
# True

# %%
b = 1

# %%
a = c = b

# %%
a = 12

# %%
b
# Out:
# 1

# %%
1.118033988749895 != 1.5 != 1.5
# Out:
# False

# %%
5 ** 0.5
# Out:
# 2.23606797749979
