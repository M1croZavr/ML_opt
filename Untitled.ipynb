# %%
import onedimensionaloptimization.optimize as optimize
from twovarextremas.utils_twovarextremas import preproc_fun
import sympy

# %%
# Примеры из методички
'-5x^5 + 4x^4 - 12x^3 + 11x^2 -2x + 1', -0.5, 0.5    #correct
'log2(x - 2) + log2(10 - x) - x^0.2', 6, 9.9    # неочевидная функция, нельзя аппроксимировать параболами и BFGS
'-3x*sin(0.75x) + exp(-2x)', 0, 2 * sympy.pi    #correct
'exp(3x) + 5exp(-2x)', 0, 1    #correct
'0.2x * log(x) + (x - 2.3)^2', 0.5, 2.5 #correct
# Out:
# ('0.2x * log(x) + (x - 2.3)^2', 0.5, 2.5)

# %%
# Пример, как можно записывать логарифм
a = preproc_fun('-5x^5 + 4x^4 - 12x^3 + 11x^2 -2x + 1')
a
# Out:
# -5*x**5 + 4*x**4 - 12*x**3 + 11*x**2 - 2*x + 1

# %%
f_res, x_res, df = optimize.golden_section_search('-3x*sin(0.75x) + exp(-2x)', 0, 2 * sympy.pi, record_info=True, plot=True)
# Out:
# Найдено значение с заданной точностью
# f(x) = -7.27435797007356, x = 2.7064759148064543

# %%
f_res, x_res # Правильно
# Out:
# (-7.27435797007356, 2.7064759148064543)

# %%
f_res, x_res, df = optimize.parabola_method('-3x*sin(0.75x) + exp(-2x)', 0, 2 * sympy.pi, record_info=True, plot=True)
# Out:
# Найдено значение с заданной точностью
# f(x) = -7.27435797007389, x = 2.70647551266415

# %%
f_res, x_res # Правильно
# Out:
# (-7.27435797007389, 2.70647551266415)

# %%
f_res, x_res, df = optimize.brent_method('-3x*sin(0.75x) + exp(-2x)', 0, 2 * sympy.pi, record_info=True, plot=True)
# Out:
# Найдено значение с заданной точностью
# f(x) = -7.27435797006297, x = 2.70647747323950

# %%
f_res, x_res # Правильно
# Out:
# (0.897632971990584, 0.109856310915669)

# %%
df
# Out:
#                    a                  b                  x                  w  \
# k
# 0          -0.118034                0.5           0.118034          -0.118034
# 1          -0.118034           0.263932           0.118034           0.263932
# 2          -0.118034  0.134553150913620           0.118034  0.134553150913620
# 3          -0.118034           0.118034  0.104468199246957           0.118034
# 4  0.104468199246957           0.118034  0.109840894763504  0.104468199246957
# 5  0.104468199246957  0.109892962425426  0.109840894763504  0.109892962425426
# 6  0.109840894763504  0.109892962425426  0.109859971569052  0.109840894763504
# 7  0.109840894763504  0.109859971569052  0.109859915560086  0.109859971569052
# 8  0.109852650262285  0.109859971569052  0.109859915560086  0.109852650262285
#
#                    v                 fx         method
# k
# 0          -0.118034  0.898112696037319  Golden search
# 1          -0.118034  0.898112696037319  Golden search
# 2           0.263932  0.898112696037319      Parabolic
# 3  0.134553150913620  0.897845969912244      Parabolic
# 4           0.118034  0.897632974525754      Parabolic
# 5  0.104468199246957  0.897632974525754      Parabolic
# 6  0.109892962425426  0.897632971896190      Parabolic
# 7  0.109840894763504  0.897632971896167      Parabolic
# 8  0.109859971569052  0.897632971896167  Golden search

# %%
f_res, x_res, df = optimize.bfgs('-3x*sin(0.75x) + exp(-2x)', 6, record_info=True)
# Out:
# Найдено значение с заданной точностью
# f(x) = -7.274357970073897, x = 2.7064755456166667

# %%
f_res, x_res # Правильно
# Out:
# (-7.2743579700738215, 2.7064754202672647)

# %%
df
# Out:
#           x     alpha         p         s         y         c     delta_fun
# k
# 0  2.610377  1.305188  2.000000  2.610377  1.427639  1.828457 -5.723612e-01
# 1  2.701381  0.086958  1.046538  0.091004  0.541294  0.168124 -3.106771e-02
# 2  2.706605  1.000000  0.005223  0.005223  0.031855  0.163969  7.872840e-04
# 3  2.706475  1.000000 -0.000129 -0.000129 -0.000788  0.163764 -9.838730e-07

# %%
from scipy import optimize as opt

# %%
f = lambda x: -5 * x ** 5 + 4 * x ** 4 - 12 * x ** 3 + 11 * x ** 2 - 2 * x + 1
opt.minimize(f, -0.5, method='BFGS')
# Out:
#       fun: 0.8976329718962657
#  hess_inv: array([[1.39800581]])
#       jac: array([1.8030405e-06])
#   message: 'Optimization terminated successfully.'
#      nfev: 20
#       nit: 3
#      njev: 10
#    status: 0
#   success: True
#         x: array([0.10986003])

# %%
from sympy.utilities.lambdify import lambdify

# %%
al = lambdify('x', a)
al_ = lambdify('x', a.diff('x'))

# %%
bfgs_method(al, al_, np.array([0.1]))
# Out:
# (array([0.10987976]), 2)
