# %%
import onedimensionaloptimization.optimize as optimize
from twovarextremas.utils_twovarextremas import preproc_fun
import sympy

# %%
# Примеры из методички
'-5x^5 + 4x^4 - 12x^3 + 11x^2 -2x + 1', -0.5, 0.5
'log2(x - 2) + log2(10 - x) - x^0.2', 6, 9.9
'-3x*sin(0.75x) + exp(-2x)', 0, 2 * sympy.pi
'exp(3x) + 5exp(-2x)', 0, 1
'0.2x * log(x) + (x - 2.3)^2', 0.5, 2.5
# Out:
# '0.2x * log(x) + (x - 2.3)^2'

# %%
a = preproc_fun('log2(x - 2) + log2(10 - x) - x^0.2')
a.subs('x', 0.5)
# Out:
# -0.870550563296124 + 2.2512917986065/log(2) + (0.405465108108164 + I*pi)/log(2)

# %%
f_res, x_res, df = optimize.golden_section_search('0.2x * log(x) + (x - 2.3)^2', 0.5, 2.5, record_info=True)
# Out:
# Найдено значение с заданной точностью

# %%
f_res, x_res # Правильно
# Out:
# (0.350977880143911, 2.12464187054829)

# %%
f_res, x_res, df = optimize.parabola_method('0.2x * log(x) + (x - 2.3)^2', 0.5, 2.5, record_info=True, plot=True)
# Out:
# Найдено значение с заданной точностью

# %%
f_res, x_res # Правильно
# Out:
# (0.350977880139661, 2.12464035689238)

# %%
f_res, x_res = optimize.brent_method('0.2x * log(x) + (x - 2.3)^2', 0.5, 2.5, record_info=False, plot=True)
# Out:
# Достигнуто максимальное количество итераций

# %%
f_res, x_res
# Out:
# (0.761652721608900, 1.49999)

# %%
df
# Out:
#           x_l  x_r         u                fu
# k
# 0    0.000000  0.5  0.309017  5.22206129101104
# 1    0.309017  0.5  0.309017  5.22206129101104
# 2    0.309017  0.5  0.309017  5.22206129101104
# 3    0.309017  0.5  0.309017  5.22206129101104
# 4    0.309017  0.5  0.309017  5.22206129101104
# ..        ...  ...       ...               ...
# 495  0.309017  0.5  0.309017  5.22206129101104
# 496  0.309017  0.5  0.309017  5.22206129101104
# 497  0.309017  0.5  0.309017  5.22206129101104
# 498  0.309017  0.5  0.309017  5.22206129101104
# 499  0.309017  0.5  0.309017  5.22206129101104
#
# [500 rows x 4 columns]

# %%
math.(-10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [10], in <module>
# ----> 1 sgn(-10)
#
# NameError: name 'sgn' is not defined

# %%
import math

# %%
def sign(x):
    if x < 0:
        return -1
    elif x > 0:
        return 1
    else:
        return 0

# %%
sign(-4)
# Out:
# -1

# %%
1 >= 1
# Out:
# True

# %%
1 <= 1
# Out:
# True

# %%
b = 1

# %%
a = c = b

# %%
a = 12

# %%
b
# Out:
# 1

# %%
1.118033988749895 != 1.5 != 1.5
# Out:
# False

# %%
5 ** 0.5
# Out:
# 2.23606797749979
