# %% [markdown]
# ## Тестирование

# %% [markdown]
# Примеры взяты: https://vk.com/away.php?to=https%3A%2F%2Fdocplayer.com%2F88015839-Etap-2-metody-resheniya-znp-pri-ogranicheniyah-tipa-ravenstva.html&cc_key=

# %%
from interiorpoint.optimize import *

# %% [markdown]
# ### Пример 1

# %%
newton_dual(fun='x**2+2*x**2-2*x-6*y-12', g=['2*x+y=-1'], x_init=[1, 1])
# Out:
# f(X): -14.333333333333334 | X: {y: 2.33333334764272, x: -1.66666667382136} | Message: Optimization terminated successfully
# (-14.333333333333334, {y: 2.33333334764272, x: -1.66666667382136})

# %% [markdown]
# ### Пример 2

# %%
newton_dual(fun='x**2+y**2', g=['2*x+y+2=0'], x_init=[0, 0])
# Out:
# f(X): 0.8 | X: {y: -0.4000000000000002, x: -0.7999999999999999} | Message: Optimization terminated successfully
# (0.8, {y: -0.4000000000000002, x: -0.7999999999999999})

# %% [markdown]
# ### Пример 3

# %%
log_barriers(fun='(x-2)**2+(y-1)**2', g=['x**2+y**2<=1'], x_init=[0, 0])
# Out:
# f(X): 1.52789578067714 | X: {y: 0.4472078544919186, x: 0.8944157089838373} | Message: Optimization terminated successfully
# (1.52789578067714, {y: 0.4472078544919186, x: 0.8944157089838373})

# %%
direct_dual_interior_point(fun='(x-2)**2+(y-1)**2', g=['x**2+y**2<=1'], x_init=[0, 0])
# Out:
# f(X): 1.5278960564663888 | X: {y: 0.44720780184055126, x: 0.8944156105839621} | Message: `gtol` termination condition is satisfied.
# (1.5278960564663888, {y: 0.44720780184055126, x: 0.8944156105839621})

# %% [markdown]
# ### Пример 4

# %%
log_barriers(fun='x+y', g=['x**2+y**2<=1'], x_init=[1, 1])
# Out:
# f(X): -1.41406888750287 | X: {y: -0.7070344437514331, x: -0.7070344437514331} | Message: Optimization terminated successfully
# (-1.41406888750287, {y: -0.7070344437514331, x: -0.7070344437514331})

# %%
direct_dual_interior_point(fun='x+y', g=['x**2+y**2<=1'], x_init=[1, 1])
# Out:
# f(X): -1.4134016718436628 | X: {y: -0.7067008359218316, x: -0.7067008359218313} | Message: `gtol` termination condition is satisfied.
# (-1.4134016718436628, {y: -0.7067008359218316, x: -0.7067008359218313})
